# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")

# %% [markdown]
# # Data Description
#
#
# ### 1. This is synthetic numeric (continuous R.V.) data.
# ### 2. Each column is generated with different a unique random process.

# %%
data_path = "../data/entropy_rv.csv"
df = pd.read_csv(data_path)
df.head()
# Out:
#    A      B      C      D      E
# 0  1  4.995  3.914  0.991  4.754
# 1  1  4.662  4.850  0.952  2.771
# 2  1  4.749  6.080  0.986  5.411
# 3  1  4.339  5.529  0.880  2.721
# 4  2  4.889  3.768  0.979  4.468

# %% [markdown]
# # Exercise 1:
#
# ### Visualize each column in the data

# %%
df.hist(figsize=(18, 8), bins=31);

# %% [markdown]
# # Exercise 2:
#
# ### for each group suggest a value that minimizes entropy (surprises)?

# %% [markdown]
# # Exercise 3:
#
# ### which group has the most variablity?
#
# ### which group has the least variablity?

# %% [markdown]
# # Exercise 4:
#
# ### which group is the easiest in suggesting values?
#
# ### which group is the hardest in suggesting values?
